# %%
from src import data
import pandas as pd
metaloader = data.MetadataLoader("tests/data/catalog-test.pkl")
meta = metaloader.load(data.Station.BND, "8bit", night_time=False)

données_traitées = pd.DataFrame.from_dict(next(meta).__dict__, orient="index").transpose()
for ligne in meta:
    données_traitées = données_traitées.append(pd.DataFrame.from_dict(ligne.__dict__, orient="index").transpose())
# Out:
# tests/data/catalog-test.pkl

# %%
données_traitées.to_excel("blah.xlsx")

# %%
données_traitées
# Out:
#                                            image_path image_compression  \
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# ..                                                ...               ...
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
# 0   /project/cq-training-1/project1/data/hdf5v7_8b...              8bit
#
#    image_offset            datetime latitude longitude altitude target_ghi  \
# ...

# %%
#catalog

# %%
catalog[catalog["BND_DAYTIME"]==True]
# Out:
#                                                              ncdf_path  \
# iso-datetime
# 2010-01-01 13:30:00                                                nan
# 2010-01-01 13:45:00                                                nan
# 2010-01-01 14:00:00                                                nan
# 2010-01-01 14:15:00                                                nan
# 2010-01-01 14:30:00                                                nan
# ...                                                                ...
# 2011-11-22 17:30:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2010-08-15 23:00:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2010-05-11 19:00:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2013-02-15 14:15:00  /project/cq-training-1/project1/data/netcdf/GO...
# 2011-02-08 17:45:00  /project/cq-training-1/project1/data/netcdf/GO...
#
#                                                         hdf5_8bit_path  \
# iso-datetime
# ...

# %%
import pickle
catalog = pickle.load(open("tests/data/catalog-test.pkl","rb"))

# %%
catalog[['hdf5_8bit_offset', 'hdf5_16bit_offset']]
# Out:
#                     BND_CLOUDINESS     BND_GHI
# iso-datetime
# 2010-01-01 00:00:00          night   -4.100000
# 2010-01-01 00:15:00          night   -4.100000
# 2010-01-01 00:30:00          night   -4.100000
# 2010-01-01 00:45:00          night   -4.100000
# 2010-01-01 01:00:00          night   -4.100000
# ...                            ...         ...
# 2010-08-15 23:00:00          clear  304.240000
# 2010-05-11 19:00:00       variable  722.440000
# 2013-02-15 14:15:00         cloudy   57.306667
# 2010-03-03 01:00:00          night   -3.500000
# 2011-02-08 17:45:00          clear  673.806667
#
# [2100 rows x 2 columns]
